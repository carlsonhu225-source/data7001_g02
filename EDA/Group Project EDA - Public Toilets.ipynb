# %% [markdown]
# # Group Project Dataset EDA
#
# Exploratory data analysis of selected datasets from data.gov

# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv("data/toiletmapexport_250801_074429.csv")
df.head(10)
# Out:
#    FacilityID                                   URL                   Name  \
# 0           1   https://toiletmap.gov.au/facility/1    Sandy Beach Reserve
# 1           2   https://toiletmap.gov.au/facility/2          Point Reserve
# 2           3   https://toiletmap.gov.au/facility/3   Success Hill Reserve
# 3           4   https://toiletmap.gov.au/facility/4        Jubilee Reserve
# 4           5   https://toiletmap.gov.au/facility/5       Ashfield Reserve
# 5           7   https://toiletmap.gov.au/facility/7  Mary Crescent Reserve
# 6           9   https://toiletmap.gov.au/facility/9   Bassendean Oval West
# 7          15  https://toiletmap.gov.au/facility/15              Apex Park
# 8          16  https://toiletmap.gov.au/facility/16             Lions Park
# 9          17  https://toiletmap.gov.au/facility/17         Parella Street
#
#         FacilityType                    Address1        Town State  \
# 0    Park or reserve       Lost 15525, West Road  Bassendean    WA
# ...

# %%
df.info()

# Note - data dictionary seems to have all listed as text strings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24715 entries, 0 to 24714
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FacilityID         24715 non-null  int64
#  1   URL                24715 non-null  object
#  2   Name               24715 non-null  object
#  3   FacilityType       24715 non-null  object
#  4   Address1           24623 non-null  object
#  5   Town               24714 non-null  object
#  6   State              24714 non-null  object
#  7   AddressNote        2667 non-null   object
#  8   Latitude           24715 non-null  float64
#  9   Longitude          24715 non-null  float64
#  10  Parking            24715 non-null  bool
#  11  ParkingAccessible  24715 non-null  bool
#  12  ParkingNote        1914 non-null   object
#  13  KeyRequired        24715 non-null  bool
#  14  MLAK24             24715 non-null  bool
#  15  MLAKAfterHours     24715 non-null  bool
# ...

# %%
df.shape
# Out:
# (24715, 47)

# %%
df.isna().sum()
# Out:
# FacilityID               0
# URL                      0
# Name                     0
# FacilityType             0
# Address1                92
# Town                     1
# State                    1
# AddressNote          22048
# Latitude                 0
# Longitude                0
# Parking                  0
# ParkingAccessible        0
# ParkingNote          22801
# KeyRequired              0
# MLAK24                   0
# MLAKAfterHours           0
# PaymentRequired          0
# AccessNote           22842
# AdultChange              0
# ChangingPlaces           0
# BYOSling                 0
# ACShower                 0
# ACMLAK                   0
# AdultChangeNote      24562
# BabyChange               0
# BabyCareRoom             0
# BabyChangeNote       24488
# DumpPoint                0
# DPWashout                0
# DPAfterHours             0
# DumpPointNote        24475
# OpeningHours             0
# OpeningHoursNote     21324
# Male                     0
# ...

# %%
df.columns
# Out:
# Index(['FacilityID', 'URL', 'Name', 'FacilityType', 'Address1', 'Town',
#        'State', 'AddressNote', 'Latitude', 'Longitude', 'Parking',
#        'ParkingAccessible', 'ParkingNote', 'KeyRequired', 'MLAK24',
#        'MLAKAfterHours', 'PaymentRequired', 'AccessNote', 'AdultChange',
#        'ChangingPlaces', 'BYOSling', 'ACShower', 'ACMLAK', 'AdultChangeNote',
#        'BabyChange', 'BabyCareRoom', 'BabyChangeNote', 'DumpPoint',
#        'DPWashout', 'DPAfterHours', 'DumpPointNote', 'OpeningHours',
#        'OpeningHoursNote', 'Male', 'Female', 'Unisex', 'AllGender', 'Ambulant',
#        'Accessible', 'LHTransfer', 'RHTransfer', 'ToiletNote',
#        'SharpsDisposal', 'DrinkingWater', 'SanitaryDisposal',
#        'MensPadDisposal', 'Shower'],
#       dtype='object')

# %%
df_clean = df.drop(labels=['AddressNote', 'ParkingNote', 'AccessNote', 'AdultChangeNote'], axis=1)
df_clean.head(10)
# Out:
#    FacilityID                                   URL                   Name  \
# 0           1   https://toiletmap.gov.au/facility/1    Sandy Beach Reserve
# 1           2   https://toiletmap.gov.au/facility/2          Point Reserve
# 2           3   https://toiletmap.gov.au/facility/3   Success Hill Reserve
# 3           4   https://toiletmap.gov.au/facility/4        Jubilee Reserve
# 4           5   https://toiletmap.gov.au/facility/5       Ashfield Reserve
# 5           7   https://toiletmap.gov.au/facility/7  Mary Crescent Reserve
# 6           9   https://toiletmap.gov.au/facility/9   Bassendean Oval West
# 7          15  https://toiletmap.gov.au/facility/15              Apex Park
# 8          16  https://toiletmap.gov.au/facility/16             Lions Park
# 9          17  https://toiletmap.gov.au/facility/17         Parella Street
#
#         FacilityType                    Address1        Town State   Latitude  \
# ...

# %%
# Records with blank values
df.isna().any(axis=1).sum()
df_clean.isna().any(axis=1).sum()
# Out:
# 24715

# %%
df['State'].value_counts()
# Out:
# State
# NSW    7732
# VIC    5878
# QLD    4600
# WA     2785
# SA     2093
# TAS     980
# NT      325
# ACT     321
# Name: count, dtype: int64

# %%
sns.pairplot(df)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x0000017D562F0C20> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\daveb\anaconda3\Lib\site-packages\matplotlib\pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File c:\Users\daveb\anaconda3\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\daveb\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
# ...
