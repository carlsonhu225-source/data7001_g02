# %% [markdown]
# # Player Behaviour

# %%
# %run ./Load_NBA_Dataset.ipynb

# %%
# Imports
from sklearn.cluster import KMeans
import os

# %%
# Set max number of CP cores to use
os.environ['LOKY_MAX_CPU_COUNT'] = '4'

# %% [markdown]
# ### K Means
#
# Clustering player behaviour

# %%
df_cluster = df_encoded.select(
    [
        'PLAYER_ID',
        'LOC_X',
        'LOC_Y',
        'shotDistance'
    ]
)

kmeans = KMeans(n_clusters=5, random_state=47, max_iter=500).fit(df_cluster)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 2.02973841e+05, -8.29453834e-01,  1.00259020e+02,
#          1.44842825e+01],
#        [ 1.62944932e+06, -2.53393796e+00,  9.73724260e+01,
#          1.44639094e+01],
#        [ 2.54400000e+03, -1.62149606e+01,  1.02385827e+02,
#          1.34323622e+01],
#        [ 1.01108000e+05,  4.49399657e-01,  1.63222985e+02,
#          2.12007719e+01],
#        [ 1.64198761e+06, -2.08413045e+00,  9.29810297e+01,
#          1.45030863e+01]])

# %% [markdown]
# ###
